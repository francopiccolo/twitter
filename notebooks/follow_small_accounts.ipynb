# %%
from datetime import datetime, timezone

import numpy as np
import pandas as pd

from utils import get_api, get_users_from_user_ids, make_users_df

# %%
# Get my followers (not necessary for now)

# %%
# Get all followers ids from target big account
api = get_api()
screen_name = 'MrCluni'
follower_ids = iterate_over_cursors(function=api.get_follower_ids, screen_name=screen_name)
print(len(follower_ids))
# Out:
# 19126

# %%
# Get a subset of followers ids from target big account
# Big accounts: therealbuni, MrCluni, patriciomolina, EstebanCervi
api = get_api()
screen_name = 'EstebanCervi'
follower_ids = api.get_follower_ids(screen_name=screen_name)
print(len(follower_ids))
# Out:
# 5000

# %%
num_users = 201
followers = get_users_from_user_ids(follower_ids[:num_users])
followers_df = make_users_df(followers, screen_name)

# %%
# Get users I already checked
df_users_played = pd.read_csv('./data/users_played.csv')

# %%
# Pick users to check
num_users = 10
friends_followers_ratio_threshold = 4
days_since_last_status_threshold = 0
friends_threshold = 30
followers_threshold = 10

friends_followers_ratio_mask = followers_df['friends_followers_ratio'] > friends_followers_ratio_threshold
days_since_last_status_mask = followers_df['days_since_last_status'] <= days_since_last_status_threshold
friends_mask = followers_df['friends_count'] > friends_threshold
followers_mask = followers_df['followers_count'] > followers_threshold
not_played_mask = ~followers_df['screen_name'].isin(df_users_played['screen_name'])

df_to_follow = followers_df[
        friends_followers_ratio_mask & 
        days_since_last_status_mask & 
        friends_mask & 
        not_played_mask &
        followers_mask].sample(num_users)

# %%
# View users to play
df_to_follow
# Out:
#          screen_name                location  followers_count  friends_count  \
# 12         letty_nel            Buenos aires               15            170
# 48             lumr7         Capital Federal              207           2152
# 119       loserhaha6      Córdoba, Argentina               30            549
# 97   tujavie_entanga          nowherebuthome               24            431
# 111          Nikytux                                      404           2532
# 170   andreSanchezCu  Bogotá, D.C., Colombia               41            924
# 91      pourlagaleri                                      143           1004
# 66      RosaSGoldman                                      146            845
# 101         NpolloYC                                       66            547
# 0         nnachotrip  Santa Catarina, Brasil              162            882
#
#                          created_at  favourites_count  statuses_count  \
# 12   Thu May 17 12:44:10 +0000 2018             17269             344
# 48   Thu Dec 01 02:22:49 +0000 2011              5616            1958
# 119  Sun Sep 29 07:37:39 +0000 2019             17242             501
# 97   Mon Dec 24 18:26:21 +0000 2018              5884             282
# 111  Thu Sep 17 19:16:44 +0000 2009              6129            2787
# 170  Tue Mar 17 19:20:12 +0000 2020               171              85
# 91   Tue May 28 16:55:36 +0000 2019             12283            1906
# 66   Tue Feb 07 15:46:13 +0000 2012              4019            1282
# 101  Sun Dec 01 00:48:38 +0000 2013              2088             947
# 0    Wed Oct 23 10:50:10 +0000 2019             14132            7567
#
#                   last_status  friends_followers_ratio  \
# 12  2021-11-29 06:04:21+00:00                11.333333
# 48  2021-11-29 03:38:45+00:00                10.396135
# 119 2021-11-28 20:26:18+00:00                18.300000
# 97  2021-11-29 00:59:17+00:00                17.958333
# 111 2021-11-29 00:42:21+00:00                 6.267327
# 170 2021-11-29 01:27:44+00:00                22.536585
# 91  2021-11-29 11:13:39+00:00                 7.020979
# 66  2021-11-29 01:48:17+00:00                 5.787671
# 101 2021-11-28 20:58:49+00:00                 8.287879
# 0   2021-11-29 11:27:37+00:00                 5.444444
#
#                       time_processed  days_since_last_status  \
# 12  2021-11-29 11:57:00.089920+00:00                     0.0
# 48  2021-11-29 11:57:00.089920+00:00                     0.0
# 119 2021-11-29 11:57:00.089920+00:00                     0.0
# 97  2021-11-29 11:57:00.089920+00:00                     0.0
# 111 2021-11-29 11:57:00.089920+00:00                     0.0
# 170 2021-11-29 11:57:00.089920+00:00                     0.0
# 91  2021-11-29 11:57:00.089920+00:00                     0.0
# 66  2021-11-29 11:57:00.089920+00:00                     0.0
# 101 2021-11-29 11:57:00.089920+00:00                     0.0
# 0   2021-11-29 11:57:00.089920+00:00                     0.0
#
#     source_screen_name
# 12        EstebanCervi
# 48        EstebanCervi
# 119       EstebanCervi
# 97        EstebanCervi
# 111       EstebanCervi
# 170       EstebanCervi
# 91        EstebanCervi
# 66        EstebanCervi
# 101       EstebanCervi
# 0         EstebanCervi

# %%
# Save users played
df_to_follow.to_csv('./data/users_played.csv', mode='a', index=False, header=False)

# %%
# View users played
df_users_played = pd.read_csv('./data/users_played.csv')
df_users_played.tail(10)
# Out:
#         screen_name                location followers_count friends_count  \
# 68        letty_nel            Buenos aires              15           170
# 69            lumr7         Capital Federal             207          2152
# 70       loserhaha6      Córdoba, Argentina              30           549
# 71  tujavie_entanga          nowherebuthome              24           431
# 72          Nikytux                     NaN             404          2532
# 73   andreSanchezCu  Bogotá, D.C., Colombia              41           924
# 74     pourlagaleri                     NaN             143          1004
# 75     RosaSGoldman                     NaN             146           845
# 76         NpolloYC                     NaN              66           547
# 77       nnachotrip  Santa Catarina, Brasil             162           882
#
#                         created_at favourites_count statuses_count  \
# 68  Thu May 17 12:44:10 +0000 2018            17269            344
# 69  Thu Dec 01 02:22:49 +0000 2011             5616           1958
# 70  Sun Sep 29 07:37:39 +0000 2019            17242            501
# 71  Mon Dec 24 18:26:21 +0000 2018             5884            282
# 72  Thu Sep 17 19:16:44 +0000 2009             6129           2787
# 73  Tue Mar 17 19:20:12 +0000 2020              171             85
# 74  Tue May 28 16:55:36 +0000 2019            12283           1906
# 75  Tue Feb 07 15:46:13 +0000 2012             4019           1282
# 76  Sun Dec 01 00:48:38 +0000 2013             2088            947
# 77  Wed Oct 23 10:50:10 +0000 2019            14132           7567
#
#                   last_status friends_followers_ratio  \
# 68  2021-11-29 06:04:21+00:00      11.333333333333334
# 69  2021-11-29 03:38:45+00:00      10.396135265700483
# 70  2021-11-28 20:26:18+00:00                    18.3
# 71  2021-11-29 00:59:17+00:00      17.958333333333332
# 72  2021-11-29 00:42:21+00:00       6.267326732673268
# 73  2021-11-29 01:27:44+00:00      22.536585365853657
# 74  2021-11-29 11:13:39+00:00       7.020979020979021
# 75  2021-11-29 01:48:17+00:00       5.787671232876712
# 76  2021-11-28 20:58:49+00:00       8.287878787878787
# 77  2021-11-29 11:27:37+00:00       5.444444444444445
#
#                       time_processed days_since_last_status source_screen_name
# 68  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 69  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 70  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 71  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 72  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 73  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 74  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 75  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 76  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
# 77  2021-11-29 11:57:00.089920+00:00                    0.0       EstebanCervi
